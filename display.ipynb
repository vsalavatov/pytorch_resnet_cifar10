# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/vsalavatov/pytorch_resnet_cifar10/blob/master/display.ipynb)

# %%
! git clone https://github.com/vsalavatov/pytorch_resnet_cifar10
# %cd pytorch_resnet_cifar10
# Out:
# Cloning into 'pytorch_resnet_cifar10'...
# remote: Enumerating objects: 77, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 158 (delta 45), reused 54 (delta 22), pack-reused 81
# Receiving objects: 100% (158/158), 84.33 MiB | 4.77 MiB/s, done.
# Resolving deltas: 100% (81/81), done.
# /content/pytorch_resnet_cifar10

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %run display.py\
 --names\
 'Consensus-0'\
 'Consensus-1'\
 'Consensus-2'\
 --paths\
 '/content/gdrive/MyDrive/resnet20-plain-consensus-k3/0/statistics.pickle'\
 '/content/gdrive/MyDrive/resnet20-plain-consensus-k3/1/statistics.pickle'\
 '/content/gdrive/MyDrive/resnet20-plain-consensus-k3/2/statistics.pickle'\
 --title 'ResNet-20'\
 --save 'pic.png'
